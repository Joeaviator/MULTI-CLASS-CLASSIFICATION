# %% [markdown]
# <a href="https://colab.research.google.com/github/Joeaviator/MULTI-CLASS-CLASSIFICATION/blob/main/MULTI_CLASS_CLASSIFCATION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import datasets

# %%
#Load the dataset
iris= datasets.load_diabetes()

# %%
#feature extraction
x=iris.data[:,:2]
y=iris.target

# %%
logreg=LogisticRegression()

# %%
#train the algorithm
logreg.fit(x,y)
# Out:
# LogisticRegression()

# %%
import numpy as np
x_min, x_max = x[:,0].min()-.5,x[:,0].max()+.5
y_min, y_max = x[:,1].min()-.5,x[:,1].max()+.5
#Step size between the points
h=.02
xx,yy=np.meshgrid(np.arange(x_min,x_max,h),np.arange(y_min,y_max,h))
z=logreg.predict(np.c_[xx.ravel(),yy.ravel()])

# %%
import matplotlib.pyplot as plt

z=z.reshape(xx.shape)
plt.pcolormesh(xx,yy,z,cmap=plt.cm.Paired)
#plot the original points
plt.scatter(x[:,0],x[:,1],c=y,edgecolor='k',cmap=plt.cm.Paired)
#predicted points
plt.xlim(xx.min(),xx.max())
plt.ylim(yy.min(),yy.max())
plt.xticks(())
plt.yticks(())
plt.show()
